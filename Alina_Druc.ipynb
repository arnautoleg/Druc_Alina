# %% [markdown]
# <a href="https://colab.research.google.com/github/arnautoleg/Druc_Alina/blob/main/Alina_Druc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Dataframe

# %%
df = pd.read_excel('/content/Baza_lab_9sezoane.xlsx')

# %%
df.columns
# Out:
# Index(['ID', 'TER_ADM', 'IMSP', 'ANI', 'GEN', 'S_SUPR', 'SAMPLE', 'SPT', 'AN',
#        'LAB', 'D_REC', 'D_INV', 'D_INF', 'AH3N2', 'A_NESUB', 'AH1', 'TIPB',
#        'REZ', 'VACCINAT', 'CLASIF_CAZ', 'EXUDAT', 'TRAVEL', 'T_VIZ', 'D_SRM',
#        'D_PRE', 'DEBUT', 'DIAGN', 'STAREA_P', 'TRAT_AV', 'AV', 'D_ADM_AV',
#        'DURATA_AV', 'TERAPIE_INT', 'INTUB', 'FEBRA', 'DEB_ACUT', 'ASTENIE',
#        'MIALGII', 'CEFALEE', 'TUSE', 'EXPECTOR', 'DISPNEE', 'TEMP_MAXIM',
#        'RINIT_CORIZ', 'FARINGITA', 'OTITA', 'BOLI_DIGEST', 'ALTE_TULB',
#        'BOLI_CARD', 'BOLI_BRON', 'DIAB_ZAH', 'ALTE_BOLI', 'PREZ_SARC'],
#       dtype='object')

# %%
['TER_ADM', 'ANI', 'GEN', 'S_SUPR', 'SPT', 'AN',
       'D_REC', 'AH3N2', 'A_NESUB', 'AH1', 'TIPB',
       'REZ', 'VACCINAT', 'CLASIF_CAZ', 'EXUDAT', 'TRAVEL', 'DIAGN', 'STAREA_P', 'TRAT_AV', 'AV',
       'DURATA_AV', 'TERAPIE_INT', 'INTUB', 'FEBRA', 'DEB_ACUT', 'ASTENIE',
       'MIALGII', 'CEFALEE', 'TUSE', 'EXPECTOR', 'DISPNEE', 'TEMP_MAXIM',
       'RINIT_CORIZ', 'FARINGITA', 'OTITA', 'BOLI_DIGEST', 'DIAB_ZAH', 'PREZ_SARC']
# Out:
# ['TER_ADM',
#  'ANI',
#  'GEN',
#  'S_SUPR',
#  'SPT',
#  'AN',
#  'D_REC',
#  'AH3N2',
#  'A_NESUB',
#  'AH1',
#  'TIPB',
#  'REZ',
#  'VACCINAT',
#  'CLASIF_CAZ',
#  'EXUDAT',
#  'TRAVEL',
#  'DIAGN',
#  'STAREA_P',
#  'TRAT_AV',
#  'AV',
#  'DURATA_AV',
#  'TERAPIE_INT',
#  'INTUB',
#  'FEBRA',
#  'DEB_ACUT',
#  'ASTENIE',
#  'MIALGII',
#  'CEFALEE',
#  'TUSE',
#  'EXPECTOR',
#  'DISPNEE',
#  'TEMP_MAXIM',
#  'RINIT_CORIZ',
#  'FARINGITA',
#  'OTITA',
#  'BOLI_DIGEST',
#  'DIAB_ZAH',
#  'PREZ_SARC']

# %%
df = df[['TER_ADM', 'ANI', 'GEN', 'S_SUPR', 'SPT', 'AN',
         'D_REC', 'AH3N2', 'A_NESUB', 'AH1', 'TIPB',
         'REZ', 'VACCINAT', 'CLASIF_CAZ', 'EXUDAT', 'TRAVEL', 'DIAGN', 'STAREA_P', 'TRAT_AV', 'AV',
         'DURATA_AV', 'TERAPIE_INT', 'INTUB', 'FEBRA', 'DEB_ACUT', 'ASTENIE',
         'MIALGII', 'CEFALEE', 'TUSE', 'EXPECTOR', 'DISPNEE',
         'RINIT_CORIZ', 'FARINGITA', 'OTITA', 'BOLI_DIGEST', 'DIAB_ZAH', 'PREZ_SARC']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17194 entries, 0 to 17193
# Data columns (total 37 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TER_ADM      17194 non-null  object
#  1   ANI          17057 non-null  float64
#  2   GEN          17194 non-null  object
#  3   S_SUPR       17194 non-null  object
#  4   SPT          17194 non-null  int64
#  5   AN           17194 non-null  int64
#  6   D_REC        17194 non-null  datetime64[ns]
#  7   AH3N2        17194 non-null  object
#  8   A_NESUB      17194 non-null  object
#  9   AH1          17194 non-null  object
#  10  TIPB         17194 non-null  object
#  11  REZ          17194 non-null  object
#  12  VACCINAT     17194 non-null  object
#  13  CLASIF_CAZ   17194 non-null  object
#  14  EXUDAT       17194 non-null  object
#  15  TRAVEL       17194 non-null  object
#  16  DIAGN        17194 non-null  object
#  17  STAREA_P     17194 non-null  object
#  18  TRAT_AV      17194 non-null  object
#  19  AV           17194 non-null  object
#  20  DURATA_AV    17194 non-null  int64
#  21  TERAPIE_INT  17194 non-null  object
#  22  INTUB        17194 non-null  object
#  23  FEBRA        17194 non-null  object
#  24  DEB_ACUT     17194 non-null  object
#  25  ASTENIE      17194 non-null  object
#  26  MIALGII      17194 non-null  object
#  27  CEFALEE      17194 non-null  object
#  28  TUSE         17194 non-null  object
#  29  EXPECTOR     17194 non-null  object
#  30  DISPNEE      17194 non-null  object
#  31  RINIT_CORIZ  17194 non-null  object
#  32  FARINGITA    17194 non-null  object
#  33  OTITA        17194 non-null  object
#  34  BOLI_DIGEST  17194 non-null  object
#  35  DIAB_ZAH     17194 non-null  object
#  36  PREZ_SARC    17194 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(32)
# memory usage: 4.9+ MB

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17057 entries, 0 to 17193
# Data columns (total 37 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TER_ADM      17057 non-null  object
#  1   ANI          17057 non-null  float64
#  2   GEN          17057 non-null  object
#  3   S_SUPR       17057 non-null  object
#  4   SPT          17057 non-null  int64
#  5   AN           17057 non-null  int64
#  6   D_REC        17057 non-null  datetime64[ns]
#  7   AH3N2        17057 non-null  object
#  8   A_NESUB      17057 non-null  object
#  9   AH1          17057 non-null  object
#  10  TIPB         17057 non-null  object
#  11  REZ          17057 non-null  object
#  12  VACCINAT     17057 non-null  object
#  13  CLASIF_CAZ   17057 non-null  object
#  14  EXUDAT       17057 non-null  object
#  15  TRAVEL       17057 non-null  object
#  16  DIAGN        17057 non-null  object
#  17  STAREA_P     17057 non-null  object
#  18  TRAT_AV      17057 non-null  object
#  19  AV           17057 non-null  object
#  20  DURATA_AV    17057 non-null  int64
#  21  TERAPIE_INT  17057 non-null  object
#  22  INTUB        17057 non-null  object
#  23  FEBRA        17057 non-null  object
#  24  DEB_ACUT     17057 non-null  object
#  25  ASTENIE      17057 non-null  object
#  26  MIALGII      17057 non-null  object
#  27  CEFALEE      17057 non-null  object
#  28  TUSE         17057 non-null  object
#  29  EXPECTOR     17057 non-null  object
#  30  DISPNEE      17057 non-null  object
#  31  RINIT_CORIZ  17057 non-null  object
#  32  FARINGITA    17057 non-null  object
#  33  OTITA        17057 non-null  object
#  34  BOLI_DIGEST  17057 non-null  object
#  35  DIAB_ZAH     17057 non-null  object
#  36  PREZ_SARC    17057 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(32)
# memory usage: 4.9+ MB

# %%
df.shape
# Out:
# (17057, 37)

# %% [markdown]
# # Descriptive statistics

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.stats.proportion import proportion_confint

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.stats.proportion import proportion_confint

def bar_plot_cat (el, df):

  # Calculate percentage for each category
  percentage_data = (df[el].value_counts(normalize=True, sort=False).sort_index() * 100).reset_index()
  percentage_data.columns = [el, 'Procente']

  # Calculate confidence intervals for each category
  ci_data = df[el].value_counts().apply(lambda x: proportion_confint(x, len(df), method='normal')).reset_index()
  ci_data.columns = [el, 'CI']

  # Unpack the tuple into separate columns for lower and upper bounds
  ci_data[['CI_Lower', 'CI_Upper']] = pd.DataFrame(ci_data['CI'].tolist(), index=ci_data.index)

  # Drop the original CI column
  ci_data = ci_data.drop(columns=['CI'])

  # Merge percentage and CI data
  merged_data = pd.merge(percentage_data, ci_data, on=el)

  # Create bar plot using seaborn
  plt.figure(figsize=(8, 6))
  sns.set(style="whitegrid")
  ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")

  # Set y-axis range to be from 0 to 100
  ax.set_ylim(0, 100)


  # Add percentage and 95% confidence intervals as text annotations
  for i, row in merged_data.iterrows():
     percentage = row['Procente']
     lower_ci = row['CI_Lower'] * 100
     upper_ci = row['CI_Upper'] * 100
     if len(df[el].value_counts().index) <= 3:
      plt.text(i, percentage, f'{percentage:.1f}% [{lower_ci:.1f}, {upper_ci:.1f}]', ha='center', va='bottom', color='black')
     else:
      plt.text(i, percentage, f'{percentage:.1f}%\n [{lower_ci:.1f}, {upper_ci:.1f}]', ha='center', va='bottom', color='black')
  #plt.title('Bar Plot Frecventele relative cu 95% IC')
  plt.show()
#“normal”, “agresti_coull”, “beta”, “wilson”, “binom_test”

# %%
string_columns = df.select_dtypes(include=['object', 'category'])

# %%
df.STAREA_P.value_counts().index
# Out:
# CategoricalIndex(['Neindicat', 'Medie', 'Gravă', 'Ușoară', 'Foarte gravă'], categories=['Neindicat', 'Ușoară', 'Medie', 'Gravă', 'Foarte gravă'], ordered=True, dtype='category')

# %%
categories = ['Neindicat', 'Ușoară', 'Medie', 'Gravă', 'Foarte gravă']
df['STAREA_P'] = pd.Categorical(df['STAREA_P'], categories=categories, ordered=True)

print(df['STAREA_P'])
# Out:
# 0        Neindicat
# 1            Medie
# 2        Neindicat
# 3        Neindicat
# 4        Neindicat
#            ...
# 17189    Neindicat
# 17190    Neindicat
# 17191    Neindicat
# 17192    Neindicat
# 17193    Neindicat
# Name: STAREA_P, Length: 17057, dtype: category
# Categories (5, object): ['Neindicat' < 'Ușoară' < 'Medie' < 'Gravă' < 'Foarte gravă']

# %%
for el in string_columns:
  if el != 'TER_ADM':
    bar_plot_cat (el, df)
# Out:
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")
# <ipython-input-38-6943c0ceaadd>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=el, y='Procente', data=merged_data, palette="viridis")

# %%
numeric_columns = df.select_dtypes(include=['int', 'float'])

# %%
numeric_columns
# Out:
#         ANI  SPT    AN  DURATA_AV
# 0      46.0   46  2022          0
# 1      34.0   41  2022          0
# 2      75.0   41  2022          0
# 3      67.0   41  2022          0
# 4      81.0   41  2022          0
# ...     ...  ...   ...        ...
# 17189  59.0   20  2017          0
# 17190   9.0   20  2017          0
# 17191  17.0   20  2017          0
# 17192  46.0   21  2017          0
# 17193   6.0   21  2017          0
#
# [17057 rows x 4 columns]

# %%
from matplotlib import pyplot as plt


for el in numeric_columns:
  numeric_columns[el].plot(kind='hist', bins=20, title=el)
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.show()

# %% [markdown]
# # Comparative evaluation

# %%
! pip install scikit_posthocs
# Out:
# Requirement already satisfied: scikit_posthocs in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (1.25.2)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (1.11.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (0.14.1)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (1.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from scikit_posthocs) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scikit_posthocs) (3.1.2)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels->scikit_posthocs) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels->scikit_posthocs) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scikit_posthocs import posthoc_dunn
from scipy.stats import f_oneway

def boxplot_and_heatmap(data, category_col, numerical_col, category_order):
    # Set the style of the visualization
    sns.set(style="whitegrid")

    # Define category order if needed
    # category_order = data[category_col].unique()

    print(round(df.groupby([category_col])[numerical_col].describe(), 1))

    print()

    # Create a box plot
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 2, 1)
    sns.boxplot(x=category_col, y=numerical_col, data=data, palette='Set2', order=category_order)
    plt.xlabel(category_col)
    plt.ylabel(numerical_col)
    plt.ylim(0, max(df[numerical_col]) + max(df[numerical_col])*0.2)
    plt.title('Box Plot with Comparisons Among Groups')

    # Calculate ANOVA F-test statistic
    f_statistic, f_p_value = f_oneway(*[group[1][numerical_col] for group in data.groupby(category_col)])

    # Display ANOVA F-test statistics
    print(f"ANOVA F-test: F = {f_statistic}, p = {f_p_value}")

    # posthoc dunn test, with correction for multiple testing
    dunn_df = posthoc_dunn(data, val_col=numerical_col, group_col=category_col, p_adjust="fdr_bh")

    plt.subplot(1, 2, 2)
    sns.heatmap(dunn_df, cmap='viridis', annot=True, linewidths=.5)
    plt.title('Comparisons Between {} Groups'.format(category_col))

    # Adjust layout for better spacing
    plt.tight_layout()

    # Show the plots
    plt.show()

# %%
df.DIAGN.value_counts().index
# Out:
# Index(['IACRS', 'SARI', 'Gripă'], dtype='object')

# %%
for el in numeric_columns:
  boxplot_and_heatmap(df, 'DIAGN', el, ['IACRS', 'SARI', 'Gripă'])
# Out:
#          count  mean   std  min   25%   50%   75%   max
# DIAGN
# Gripă   1680.0  27.8  23.8  0.0   6.0  20.0  50.0  92.0
# IACRS  13131.0  36.8  25.4  0.0  12.0  36.0  60.0  94.0
# SARI    2246.0  30.7  28.0  0.0   2.0  27.0  58.0  93.0
# <ipython-input-50-5b9abfd8ba1d>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=category_col, y=numerical_col, data=data, palette='Set2', order=category_order)
# ANOVA F-test: F = 128.87351817974627, p = 2.816274059807018e-56
#          count  mean   std  min  25%   50%   75%   max
# DIAGN
# Gripă   1680.0  14.2  15.2  1.0  5.0   9.0  13.0  53.0
# IACRS  13131.0  28.1  17.0  1.0  9.0  36.0  44.0  53.0
# SARI    2246.0  23.0  18.4  1.0  7.0  14.0  44.0  53.0
#
# ANOVA F-test: F = 539.1753968879148, p = 8.796108347990724e-228
# <ipython-input-50-5b9abfd8ba1d>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=category_col, y=numerical_col, data=data, palette='Set2', order=category_order)
#          count    mean  std     min     25%     50%     75%     max
# DIAGN
# Gripă   1680.0  2019.3  2.3  2014.0  2018.0  2019.0  2021.0  2023.0
# IACRS  13131.0  2021.2  1.9  2014.0  2022.0  2022.0  2022.0  2023.0
# SARI    2246.0  2018.5  2.5  2014.0  2016.0  2018.0  2021.0  2023.0
#
# ANOVA F-test: F = 1947.7062680215652, p = 0.0
# <ipython-input-50-5b9abfd8ba1d>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=category_col, y=numerical_col, data=data, palette='Set2', order=category_order)
#          count  mean  std  min  25%  50%  75%   max
# DIAGN
# Gripă   1680.0   0.1  0.6  0.0  0.0  0.0  0.0  10.0
# IACRS  13131.0   0.0  0.3  0.0  0.0  0.0  0.0   7.0
# SARI    2246.0   0.0  0.4  0.0  0.0  0.0  0.0  11.0
#
# ANOVA F-test: F = 36.67018389503276, p = 1.2837711217702484e-16
# <ipython-input-50-5b9abfd8ba1d>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=category_col, y=numerical_col, data=data, palette='Set2', order=category_order)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportion_confint


def graph_cat_per (factors, outcomes):


  for el in factors:

    # Assuming df is your DataFrame with two categorical variables, 'Comportament Manager' and 'Profesia'
    # Create a contingency table
    for out in outcomes:
      contingency_table = pd.crosstab(df[out], df[el[0]])

      # Define the desired order for variables

      variable1_order = el[1]  # Replace with your actual category names

      # Convert variables to CategoricalDtype with specified order
      contingency_table.index = pd.Categorical(contingency_table.index, categories=variable1_order, ordered=True)


      # Sort the index and columns based on the specified order
      contingency_table.sort_index(axis=0, inplace=True)
      contingency_table.sort_index(axis=1, inplace=True)
      contingency_table

      # Perform the Chi-squared test
      chi2, p, _, _ = chi2_contingency(contingency_table)

      # Print the Chi-squared statistic and p-value
      # print(f"Chi-squared: {chi2}")
      # print(f"P-value: {p}")

      # Calculate column percentages
      col_percentages = contingency_table.div(contingency_table.sum(axis=0), axis=1) * 100

      # Create a new DataFrame for formatted annotations
      annot_data = pd.DataFrame(index=col_percentages.index, columns=col_percentages.columns)
      for i in range(contingency_table.shape[0]):
         for j in range(contingency_table.shape[1]):
             annot_data.iloc[i, j] = f"{col_percentages.iloc[i, j]:.1f}%"

      # Calculate exact confidence intervals for each cell
      confidence_intervals = pd.DataFrame(index=col_percentages.index, columns=col_percentages.columns)
      for i in range(contingency_table.shape[0]):
          for j in range(contingency_table.shape[1]):
             data = contingency_table.iloc[:, j].values
             ci = proportion_confint(data[i], nobs=sum(data), method='beta')
             confidence_intervals.iloc[i, j] = (ci[0] * 100, ci[1] * 100)

      # Increase the size of the plot
      plt.figure(figsize=(10, 6))

      # Plot the heatmap with formatted annotations
      sns.heatmap(col_percentages, annot=annot_data, fmt="", cmap="coolwarm")

      # Add Chi-squared statistic and p-value as text annotations
      plt.text(0.5, -0.5, f"Chi-squared: {chi2:.2f}", ha='center', va='center', fontsize=12, color='black')
      plt.text(0.5, -0.7, f"P-value: {p:.4f}", ha='center', va='center', fontsize=12, color='black')

      # Annotate each cell with exact confidence interval
      for i in range(contingency_table.shape[0]):
         for j in range(contingency_table.shape[1]):
             plt.text(j + 0.5, i + 0.8, f"CI {confidence_intervals.iloc[i, j][0]:.1f}-{confidence_intervals.iloc[i, j][1]:.1f}", ha='center', va='top', fontsize=10, color='black')



      # Rotate y-axis tick labels to a horizontal position
      plt.yticks(rotation=0)
      plt.title(f'{el[0]} versus {out}. Relative frequency 95%CI')
      plt.show()

# %%
string_columns.columns
# Out:
# Index(['TER_ADM', 'GEN', 'S_SUPR', 'AH3N2', 'A_NESUB', 'AH1', 'TIPB', 'REZ',
#        'VACCINAT', 'CLASIF_CAZ', 'EXUDAT', 'TRAVEL', 'DIAGN', 'STAREA_P',
#        'TRAT_AV', 'AV', 'TERAPIE_INT', 'INTUB', 'FEBRA', 'DEB_ACUT', 'ASTENIE',
#        'MIALGII', 'CEFALEE', 'TUSE', 'EXPECTOR', 'DISPNEE', 'RINIT_CORIZ',
#        'FARINGITA', 'OTITA', 'BOLI_DIGEST', 'DIAB_ZAH', 'PREZ_SARC'],
#       dtype='object')

# %%
factors = []

for el in ['GEN', 'S_SUPR', 'AH3N2', 'A_NESUB', 'AH1', 'TIPB', 'REZ',
           'VACCINAT', 'CLASIF_CAZ', 'EXUDAT', 'TRAVEL', 'DIAGN', 'STAREA_P',
           'TRAT_AV', 'AV', 'TERAPIE_INT', 'INTUB', 'FEBRA', 'DEB_ACUT', 'ASTENIE',
           'MIALGII', 'CEFALEE', 'TUSE', 'EXPECTOR', 'DISPNEE', 'RINIT_CORIZ',
           'FARINGITA', 'OTITA', 'BOLI_DIGEST', 'DIAB_ZAH', 'PREZ_SARC']:
           factors.append([el, ['IACRS', 'SARI', 'Gripă']])




outcomes = ['DIAGN']
graph_cat_per (factors, outcomes)

# %%
df.to_excel('Alina_Druc.xlsx')
